# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrkomiljon/google-colab-/blob/main/Copy_of_04_VISUAL_AMALIYOT_04_distribution_JAVOBLAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 4-AMALIYOT. Distribution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Ushbu amaliyotda uybor.uz saytidan yuklab olingan ma'lumotlar tahlili bilan shu'gullanamiz.

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/uybor_scrapping.csv?raw=true")
df.head()
# Out:
#                                             location  ...        lng
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...  ...  69.281049
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  ...  69.261104
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...  ...  69.223683
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...  ...  69.196862
# 4  город Ташкент, Чиланзарский район, площадь Актепа  ...  69.210831
#
# [5 rows x 9 columns]

# %% [markdown]
# #### Yuqoridagi jadvalda Toshkent shahridagi sotildagian uylar haqida ma'lumotlar jamlangan.
#
# ## 1-VAZIFA. Jadvaldan xonalari 5 xonadan ko'p bo'lgan, narxi 200000 mingdan, maydoni 250kv.m dan ortiq bo'lgan uylarni tashlab yuboring

# %%
df=df[df.rooms<6] 
df=df[df.price<200000] 
df=df[df['size']<250.0] 
df.head()
# Out:
#                                             location  ...        lng
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...  ...  69.281049
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  ...  69.261104
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...  ...  69.223683
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...  ...  69.196862
# 4  город Ташкент, Чиланзарский район, площадь Актепа  ...  69.210831
#
# [5 rows x 9 columns]

# %%
df.shape
# Out:
# (7216, 9)

# %%
#@title Natija
df=df[df['rooms']<6]
df=df[df['size']<250]
df=df[df['price']<200000]
df.shape
# Out:
# (7216, 9)

# %% [markdown]
# ## 2-VAZIFA. `subplot` yordamida uylarning narxi va xonalar soni taqsimoti grafiklarini yonma yon chizing

# %%
fig, ax= plt.subplots(1, 2, figsize=(10,5))
sns.histplot(ax=ax[0], data=df, x='price')
sns.histplot(ax=ax[1], data=df, x='size')
ax[0].set_title('Price')
ax[1].set_title('size')
plt.show()

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(data=df, x='price')
plt.subplot(1,2,2)
sns.histplot(data=df, x='size')
plt.show()

# %% [markdown]
# ### 2-VAZIFA. Uylarning narxi taqsimoti va narx va maydoni o'rtasidagi bog'liqlik grafiklarini bitta chizmada ustma ust chiqaring.

# %%
fig, ax= plt.subplots(2, 1, figsize=(10,10))
sns.histplot(ax=ax[0], data=df, x='price')
sns.scatterplot(ax=ax[1], data=df, x='size', y='price')
ax[0].set_title('Price')
ax[1].set_title('size')
plt.show()

# %%
#@title Kutilgan natija
fig, ax = plt.subplots(2, 1, figsize=(10,10))
# Umumiy chizma nomini beramiz:
sns.histplot(ax=ax[0], data=df, x='price')
sns.scatterplot(ax=ax[1], data=df, x=df['size'], y=df['price'])
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Quyidagi grafikni chizing. Ahamiyat bering, oxirgi grafikda tumanlar bo'yicha uylarning o'rtacha narxi tasvirlangan.

# %%
# Tumanlar bo'yicha jamlangan df
distdf = df.groupby('district').mean()
fig, ax = plt.subplots(2, 2, figsize=(15,10))
sns.histplot(ax=ax[0, 0], data=df, x='price')
sns.histplot(ax=ax[0, 1], data=df, x='size')
sns.scatterplot(ax=ax[1, 0], data=df, x='size', y='price')
sns.barplot(ax=ax[1, 1], x=distdf.index, y=distdf['price'])
# Har bir grafik uchun nom:
ax[0,0].set_title("Uylarning narx buyicha taqsimoti")
ax[0,1].set_title("Uylarning maydoni buyicha taqsimoti")
ax[1,0].set_title("Uylarning narxi va maydoni buyicha taqsimoti")
ax[1,1].set_title("Tumanlar buyicha urtacha narxlar")
plt.xticks(rotation=90)
plt.show()

# %%
#@title Kutilgan natija

# Tumanlar bo'yicha jamlangan df
distdf = df.groupby('district').mean() 

#Grafiklarni chizamiz
fig, ax = plt.subplots(2, 2, figsize=(15,10))
# Umumiy chizma nomini beramiz:
sns.histplot(ax=ax[0, 0], data=df, x='price')
sns.histplot(ax=ax[0, 1], data=df, x='size')
sns.scatterplot(ax=ax[1, 0], data=df, x=df['size'], y=df['price'])
sns.barplot(ax=ax[1, 1], x=distdf.index, y=distdf['price'])
# Har bir grafik uchun nom:
ax[0,0].set_title("Uylarning narxi bo'yicha taqsimoti")
ax[0,1].set_title("Uylarning maydoni bo'yicha taqsimoti")
ax[1,0].set_title("Uylarning narxi va maydoni o'rtasioda bog'liqlik")
ax[1,1].set_title("Tumanlar bo'yicha o'rtacha narxlar")
plt.xticks(rotation=90)
plt.show()

# %%
distdf = df.groupby('district').mean()

# %%
distdf
# Out:
#                       rooms       size  ...        lat        lng
# district                                ...
# Бектемирский       2.750000  62.525000  ...  41.269078  69.306593
# Мирабадский        2.866856  85.911232  ...  41.292108  69.280130
# Мирзо-Улугбекский  2.500750  68.157076  ...  41.330483  69.333124
# Олмазорский        2.693487  76.348161  ...  41.342919  69.226783
# Сергелийский       2.740260  74.046623  ...  41.222111  69.237051
# Учтепинский        2.659379  65.559045  ...  41.288672  69.180468
# Чиланзарский       2.339341  61.422039  ...  41.277260  69.201484
# Шайхантахурский    2.853521  79.416704  ...  41.322853  69.233255
# Юнусабадский       2.617577  71.286983  ...  41.353297  69.287997
# Яккасарайский      2.479675  70.965837  ...  41.280976  69.252291
# Янгихаётский       2.642857  57.867143  ...  41.235485  69.226044
# Яшнободский        2.461024  66.532183  ...  41.296459  69.322575
#
# [12 rows x 7 columns]
